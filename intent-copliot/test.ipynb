# %%
import promptflow

# %%
# !pf init . --entry intent.py --function extract_intent --prompt-template user_prompt_template=user_intent_zero_shot.md
# Out:
# [promptflow-cli][INFO] - Creating flow from existing folder...
# [promptflow-cli][INFO] - Change working directory to .. /mnt/batch/tasks/shared/LS_root/mounts/clusters/chenlujiao1/code/MyLC/intent-copliot
# [promptflow-cli][INFO] - Overwriting /mnt/batch/tasks/shared/LS_root/mounts/clusters/chenlujiao1/code/MyLC/intent-copliot/extract_intent_tool.py...
# [promptflow-cli][INFO] - Creating /mnt/batch/tasks/shared/LS_root/mounts/clusters/chenlujiao1/code/MyLC/intent-copliot/.promptflow/flow.tools.json...
# [promptflow-cli][INFO] - Creating /mnt/batch/tasks/shared/LS_root/mounts/clusters/chenlujiao1/code/MyLC/intent-copliot/flow.dag.yaml...
# [promptflow-cli][INFO] - Creating /mnt/batch/tasks/shared/LS_root/mounts/clusters/chenlujiao1/code/MyLC/intent-copliot/flow.meta.yaml...
# [promptflow-cli][INFO] - Done. Generated flow in folder: /mnt/batch/tasks/shared/LS_root/mounts/clusters/chenlujiao1/code/MyLC/intent-copliot.

# %%
# %%writefile .env
# CHAT_DEPLOYMENT_NAME=turbo-35
# AZURE_OPENAI_API_KEY=7123602c74c8447e9137b562388ae55c
# AZURE_OPENAI_API_BASE=https://pmopenai.openai.azure.com/
# Out:
# Writing .env

# %%
# !pf run --input ./data/denormalized-flat.jsonl --env .env
# Out:
# 2023-06-30 07:04:48 +0000  458150 execution.flow     INFO     Root flow run not found in run storage 'DummyRunStorage', will create a new root flow run. Run id: 'abb96430-9444-4f6e-86aa-78b7e81c70a9', flow id: 'default_flow_id'
# 2023-06-30 07:04:48 +0000  458150 execution.flow     INFO     Executing node user_prompt_template. node run id: abb96430-9444-4f6e-86aa-78b7e81c70a9_user_prompt_template_0
# 2023-06-30 07:04:48 +0000  458150 execution.flow     INFO     Node user_prompt_template completes.
# 2023-06-30 07:04:48 +0000  458150 execution.flow     INFO     Executing node extract_intent. node run id: abb96430-9444-4f6e-86aa-78b7e81c70a9_extract_intent_0
# 2023-06-30 07:04:49 +0000  458150 execution.flow     INFO     Node extract_intent completes.
# 2023-06-30 07:04:49 +0000  458150 execution.bulk     INFO     Finished 1 / 1 lines.
# ...

# %%
# !pf run_bulk --input ./data/denormalized-flat.jsonl --output ./outputs/ --env .env
# Out:
# 2023-06-30 07:05:10 +0000  458269 execution.flow     INFO     Root flow run not found in run storage 'DummyRunStorage', will create a new root flow run. Run id: '1f67d488-b8d5-4d50-82ad-f495337f67ba', flow id: 'default_flow_id'
# 2023-06-30 07:05:10 +0000  458269 execution.flow     INFO     Executing node user_prompt_template. node run id: 1f67d488-b8d5-4d50-82ad-f495337f67ba_user_prompt_template_0
# 2023-06-30 07:05:10 +0000  458269 execution.flow     INFO     Executing node user_prompt_template. node run id: 1f67d488-b8d5-4d50-82ad-f495337f67ba_user_prompt_template_1
# 2023-06-30 07:05:10 +0000  458269 execution.flow     INFO     Executing node user_prompt_template. node run id: 1f67d488-b8d5-4d50-82ad-f495337f67ba_user_prompt_template_2
# 2023-06-30 07:05:10 +0000  458269 execution.flow     INFO     Executing node user_prompt_template. node run id: 1f67d488-b8d5-4d50-82ad-f495337f67ba_user_prompt_template_3
# ...

# %%
# !pf run_bulk --input ./data/denormalized-flat.jsonl --output ./outputs_variants/ --env .env
# Out:
# 2023-06-30 07:15:36 +0000  459890 execution.flow     INFO     Root flow run not found in run storage 'DummyRunStorage', will create a new root flow run. Run id: '612fa1ea-f280-49f8-9e84-0655e88cb216', flow id: 'default_flow_id'
# 2023-06-30 07:15:36 +0000  459890 execution.flow     INFO     Executing node user_prompt_template. node run id: 612fa1ea-f280-49f8-9e84-0655e88cb216_user_prompt_template_0
# 2023-06-30 07:15:36 +0000  459890 execution.flow     INFO     Executing node user_prompt_template. node run id: 612fa1ea-f280-49f8-9e84-0655e88cb216_user_prompt_template_1
# 2023-06-30 07:15:36 +0000  459890 execution.flow     INFO     Executing node user_prompt_template. node run id: 612fa1ea-f280-49f8-9e84-0655e88cb216_user_prompt_template_2
# 2023-06-30 07:15:36 +0000  459890 execution.flow     INFO     Executing node user_prompt_template. node run id: 612fa1ea-f280-49f8-9e84-0655e88cb216_user_prompt_template_3
# ...
